# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import pandas as pd

# %%
#Retirando os dados do Software Microsoft Excel

#Outputs FEMAP - Longitudinal, Transversal e Shear Stress

ForceX = pd.read_excel (r'C:\Users\Supervisor\Desktop\TCC\Planilhas\Propriedades do Prepreg - Experimental_Otimizador.xlsx', sheet_name = 'Planilha1', usecols = 'A')     
Force_Xi = ForceX.to_numpy()     #pego uma sequência de valores e transforma em números
Force_X1 = Force_Xi  [0:]              #fez isso para não pegar a cédula com string
Force_x = Force_X1

deslocamentoX = pd.read_excel (r'C:\Users\Supervisor\Desktop\TCC\Planilhas\Propriedades do Prepreg - Experimental_Otimizador.xlsx', sheet_name = 'Planilha1', usecols = 'B')     
deslocamento_Xi = deslocamentoX.to_numpy()     #pego uma sequência de valores e transforma em números
deslocamento_X1 = deslocamento_Xi  [0:]              #fez isso para não pegar a cédula com string
deslocamento_x = deslocamento_X1

máximoX = pd.read_excel (r'C:\Users\Supervisor\Desktop\TCC\Planilhas\Propriedades do Prepreg - Experimental_Otimizador.xlsx', sheet_name = 'Planilha1', usecols = 'M')     
máximo_Xi = máximoX.to_numpy()     #pego uma sequência de valores e transforma em números
máximo_X1 = máximo_Xi  [0:]              #fez isso para não pegar a cédula com string
máximo_x = máximo_X1

máximodeslocamentoX = pd.read_excel (r'C:\Users\Supervisor\Desktop\TCC\Planilhas\Propriedades do Prepreg - Experimental_Otimizador.xlsx', sheet_name = 'Planilha1', usecols = 'N')     
máximodeslocamento_Xi = máximodeslocamentoX.to_numpy()     #pego uma sequência de valores e transforma em números
máximodeslocamento_X1 = máximodeslocamento_Xi  [0:]              #fez isso para não pegar a cédula com string
máximodeslocamento_x = máximodeslocamento_X1

plyX = pd.read_excel (r'C:\Users\Supervisor\Desktop\TCC\Planilhas\Propriedades do Prepreg - Experimental_Otimizador.xlsx', sheet_name = 'Planilha1', usecols = 'P')     
ply_Xi = plyX.to_numpy()     #pego uma sequência de valores e transforma em números
ply_X1 = ply_Xi  [0:]              #fez isso para não pegar a cédula com string
ply_x = ply_X1

ply2X = pd.read_excel (r'C:\Users\Supervisor\Desktop\TCC\Planilhas\Propriedades do Prepreg - Experimental_Otimizador.xlsx', sheet_name = 'Planilha1', usecols = 'Q')     
ply2_Xi = ply2X.to_numpy()     #pego uma sequência de valores e transforma em números
ply2_X1 = ply2_Xi  [0:]              #fez isso para não pegar a cédula com string
ply2_x = ply2_X1

ply3X = pd.read_excel (r'C:\Users\Supervisor\Desktop\TCC\Planilhas\Propriedades do Prepreg - Experimental_Otimizador.xlsx', sheet_name = 'Planilha1', usecols = 'R')     
ply3_Xi = ply3X.to_numpy()     #pego uma sequência de valores e transforma em números
ply3_X1 = ply3_Xi  [0:]              #fez isso para não pegar a cédula com string
ply3_x = ply3_X1

ply4X = pd.read_excel (r'C:\Users\Supervisor\Desktop\TCC\Planilhas\Propriedades do Prepreg - Experimental_Otimizador.xlsx', sheet_name = 'Planilha1', usecols = 'S')     
ply4_Xi = ply4X.to_numpy()     #pego uma sequência de valores e transforma em números
ply4_X1 = ply4_Xi  [0:]              #fez isso para não pegar a cédula com string
ply4_x = ply4_X1

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(deslocamento_x,Force_x, '-o', label = 'Load: 0 a 9600 [N]',color = 'slateblue', lw = 2, ms = 3, markerfacecolor = 'black', markeredgecolor = 'k')
ax.plot(máximodeslocamento_x,máximo_x, '-', label = 'Max. Load for Failure: Layup 01',color = 'red', lw = 2, ms = 0)
plt.legend (loc='lower right', fontsize = 14, ncol =1)
plt.title ('Force x Displacement - Layup 01', fontsize = 20)
plt.xlabel ('Displacement [mm]', fontsize = 18)
plt.ylabel ('Force [N]', fontsize = 18)
ax.grid(which='major', color='silver', linewidth=0.8)
ax.grid(which='minor', color='silver', linestyle=':', linewidth=0.5)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.minorticks_on()

fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(ply_x,Force_x, '-o', label = 'Layup 01: Ply 1',color = 'slateblue', lw = 2, ms = 3, markerfacecolor = 'black', markeredgecolor = 'k')
ax.plot(ply2_x,Force_x, '-o', label = 'Layup 01: Ply 2',color = 'violet', lw = 2, ms = 3, markerfacecolor = 'black', markeredgecolor = 'k')
ax.plot(ply3_x,Force_x, '-o', label = 'Layup 01: Ply 3',color = 'y', lw = 2, ms = 3, markerfacecolor = 'black', markeredgecolor = 'k')
ax.plot(ply4_x,Force_x, '-o', label = 'Layup 01: Ply 4',color = 'green', lw = 2, ms = 3, markerfacecolor = 'black', markeredgecolor = 'k')
plt.legend (loc='lower right', fontsize = 14, ncol =1)
plt.title ('Force x Failure Index - Layup 01', fontsize = 20)
plt.xlabel ('Failure Index of Tsai-Wu [-]', fontsize = 18)
plt.ylabel ('Forcec [N]', fontsize = 18)
ax.grid(which='major', color='silver', linewidth=0.8)
ax.grid(which='minor', color='silver', linestyle=':', linewidth=0.5)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.minorticks_on()

fig.tight_layout()

# %%
a = 4.9060
a1 = 3

b = 5.0992
b1 = 2

c = 4.9889
c1 = 1

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(c1,c, 'o', label = 'Layup 01 - [0/90/0/90]s',color = 'red')
ax.plot(b1,b, 'o', label = 'Layup 02 - [45/-45/45/-45]s',color = 'black')
ax.plot(a1,a, 'o', label = 'Layup 03 - [0/90/45/-45]s',color = 'blue')
plt.legend (loc='upper right', fontsize = 12, ncol =1)
plt.title ('Displacement of Layup Configuration', fontsize = 20, style='italic')
plt.xlabel ('Number of Layup Configuration [-]', fontsize = 14, style='italic')
plt.ylabel ('Displacement [mm]', fontsize = 14, style='italic')
ax.grid(which='major', color='silver', linewidth=0.8)
ax.grid(which='minor', color='silver', linestyle=':', linewidth=0.5)
ax.minorticks_on()

fig.tight_layout()
